# %% [markdown]
# # Coding Homework 9: [put your name here]
#
# Go through this notebook, following the instructions!
#
# > TAs will mark this assignment by checking ***MarkUs*** autotests.

# %% [markdown]
# Summary of gallup polling

# %% [markdown]
# We begin by importing dataset and the libraries we will use.

# %%
import pandas as pd
import numpy as np
from sklearn import tree, model_selection
happiness2017 = pd.read_csv("happiness2017.csv")

# %% [markdown]
# #### Q1: Add a new column to `happiness2017` called `life_exp_category` which is `True` for countries with life expectency higher than 65 years, and `False` otherwise.

# %%
happiness2017["life_exp_category"] = happiness2017['life_exp'] > 65

# %%
# test_Q1
assert sum(happiness2017.life_exp_category) == 573, "ACTUAL HINT"

# %% [markdown]
# Now divide the data into a training set and testing set using an 80/20 split.

# %%
np.random.seed(1985) # do NOT change this line, it ensures our testing code works properly

train, test = model_selection.train_test_split(happiness2017, test_size=.2, train_size=.8)

# %% [markdown]
# ### Q2: Train a classification tree `clf` to predict which countries have good vs poor life expectancy, using only the `social_support` variable as a predictor.

# %%
clf = tree.DecisionTreeClassifier()

data_selectfeatures = train[["life_exp_category", "social_support"]].dropna()

X = data_selectfeatures.iloc[:,1:]
Y = data_selectfeatures.life_exp_category

clf.fit(X, Y)
# Out:
# DecisionTreeClassifier()

# %%
# test_Q2
assert False, "Make sure to train on the test dataset."
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[91], line 2
#       1 # test_Q2
# ----> 2 assert False, "Make sure to train on the test dataset."
#
# AssertionError: Make sure to train on the test dataset.

# %% [markdown]
# Now you can visualize your tree! (You can figure our which class is which by counting.)

# %%
_ = tree.plot_tree(clf)
clf.predict([[.43],[.95],[.5]])
# Out:
# /usr/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([False,  True,  True])
# Error in callback <function flush_figures at 0x7f602c10a8e0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /usr/lib/python3.11/site-packages/matplotlib_inline/backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# File /usr/lib/python3.11/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
# ...

# %% [markdown]
# ### Q3:
# a) Does your decision tree predict that a country with `social_support = .43` has good life expectancy?
# b) what if `social_support = .95`
# c) what if `social_support = .5`

# %%
Q3a = None # Replace this with True or False
Q3b = None # Replace this with True or False
Q3c = None # Replace this with True or False

# %%
# test_Q3
assert (Q3a, Q3b, Q3c) == (False, True, True), "Try clf.predict(). Use google if you don't understand how to use it" # OR not Q3, that is the question
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[94], line 2
#       1 # test_Q3
# ----> 2 assert (Q3a, Q3b, Q3c) == (False, False, True), "Try clf.predict(). Use google if you don't understand how to use it" # OR not Q3, that is the question
#
# AssertionError: Try clf.predict(). Use google if you don't understand how to use it

# %% [markdown]
# You will probably agree that this decision tree seems overly complex, so now make and train a new classification tree `clf2` with a maximum depth of 2.

# %%
clf2 = tree.DecisionTreeClassifier(max_depth=3)
clf2.fit(X,Y)
_ = tree.plot_tree(clf2, class_names=["Poor", "Good"])
clf2.predict([[.43],[.95],[.5]])
# Out:
# /usr/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([False,  True, False])
# /usr/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([False,  True, False])

# %% [markdown]
# ### Q4: Reanswer Q3 with `clf2`.

# %%
Q4a = None # Replace this with True or False
Q4b = None # Replace this with True or False
Q4c = None # Replace this with True or False

# %%
# test_Q4
assert (Q4a, Q4b, Q4c) == (False, True, False), "Try clf.predict() OR you can read off the answer from plot of the tree if you figure out the class labels."

# %% [markdown]
# ### Q4: Now train another classification tree `clf2` using `logGDP`. `social_support`, `freedom`, and `generosity` as potential predictors.

# %%
clf2 = tree.DecisionTreeClassifier()

# %%
# test_Q4

# %% [markdown]
# #### Q5: What does clf2 predict a country with logGDP=__, freedom=__, generosity=__,

# %%
happiness2017.social_support
# Out:
# 0       0.450662
# 1       0.552308
# 2       0.539075
# 3       0.521104
# 4       0.520637
#           ...
# 1415    0.896476
# 1416    0.799274
# 1417    0.765839
# 1418    0.735800
# 1419    0.768425
# Name: social_support, Length: 1420, dtype: float64
