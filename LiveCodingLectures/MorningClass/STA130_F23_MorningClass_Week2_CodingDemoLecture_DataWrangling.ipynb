# %% [markdown]
# # Data Wrangling
# - Reading Data
# - QC (*especially* missing values or `NaN`)
# -` .groupby()` and `value_counts()`
# - Subsetting (boolean selection)
# - Adding Columns
# - Sorting

# %%
1+1
# Out:
# 2

# %%
import pandas as pd
ab = pd.read_csv("../../amazonbooks.csv", encoding = "ISO-8859-1")

# %%
! ls ../..
# Out:
# amazonbooks.csv				   STA130_F23_Syllabus_html2.ipynb
# avatar.csv				   STA130_F23_Syllabus_html.ipynb
# challengerdata.csv			   STA130_F23_Syllabus.ipynb
# coffee_ratings.csv			   STA130_HW_1.ipynb
# course_project_template			   STA130_HW_1_tester.ipynb
# DoSS_W23_Departmental_Meeting_MScAC.ipynb  STA130_HW_2.ipynb
# F22-ProjectTemplate.git			   STA130_HW_2_tester.ipynb
# F22_STA130				   STA130_MT.ipynb
# HorP_DT					   STA130_ProblemSet1
# HorP_DT.pdf				   STA130_ProblemSet2
# hw3					   STA130_ProblemSet3
# hw4					   STA130_ProblemSet6
# hw5					   STA130_ProblemSet7-Week8
# hw6					   STA130_ProblemSet8-Week10
# hw7					   STA130_ProblemSet9-Week11
# hw8					   STA130_TUT_1
# hw9					   STA130_TUT_1-2.ipynb
# im					   STA130_TUT_2
# mscac					   STA130_TUT_2.ipynb
# oly12athletes.csv			   STA130-W22-ProblemSet6.git
# oly12countries.csv			   STA130-W22-ProblemSet9.git
# preamble.tex				   STA130_Week11_Demo
# pymc.ipynb				   STA130_Week12_Slides
# ...

# %%
ab
# Out:
#                                                  Title               Author  \
# 0    1,001 Facts that Will Scare the S#*t Out of Yo...          Cary McNeal
# 1    21: Bringing Down the House - Movie Tie-In: Th...          Ben Mezrich
# 2         100 Best-Loved Poems (Dover Thrift Editions)                Smith
# 3              1421: The Year China Discovered America        Gavin Menzies
# 4      1493: Uncovering the New World Columbus Created      Charles C. Mann
# ..                                                 ...                  ...
# 320                            Where the Sidewalk Ends     Shel Silverstein
# 321                                    White Privilege  Paula S. Rothenberg
# 322                                Why I wore lipstick        Geralyn Lucas
# 323  Worlds Together, Worlds Apart: A History of th...        Robert Tignor
# 324                                  Wuthering Heights         Emily Bronte
#
# ...

# %%
ab.shape
# Out:
# (325, 13)

# %%
ab.describe()
# Out:
#        List Price  Amazon Price    NumPages     Pub year      Height  \
# count  324.000000    325.000000  323.000000   324.000000  321.000000
# mean    18.579753     13.333846  335.857585  2002.206790    8.163240
# std     14.252829     13.727679  161.984389    10.629002    0.918739
# min      1.500000      0.770000   24.000000  1936.000000    5.100000
# 25%     13.950000      8.600000  208.000000  1998.000000    7.900000
# 50%     15.000000     10.200000  320.000000  2005.000000    8.100000
# 75%     19.950000     13.130000  416.000000  2010.000000    8.500000
# max    139.950000    139.950000  896.000000  2011.000000   12.100000
#
#             Width       Thick   Weight_oz
# count  320.000000  324.000000  316.000000
# mean     5.585000    0.907716   12.487975
# std      0.874057    0.368625    6.644648
# min      4.100000    0.100000    1.200000
# 25%      5.200000    0.600000    7.800000
# 50%      5.400000    0.900000   11.200000
# 75%      5.900000    1.100000   16.000000
# ...

# %%
# ab.describe() is a METHOD (function)
# this is an attribute
ab.dtypes
# Out:
# Title             object
# Author            object
# List Price       float64
# Amazon Price     float64
# Hard_or_Paper     object
# NumPages         float64
# Publisher         object
# Pub year         float64
# ISBN-10           object
# Height           float64
# Width            float64
# Thick            float64
# Weight_oz        float64
# dtype: object

# %%
# pd.Series / pd.DataFrame
(ab.Hard_or_Paper == 'H').sum()# coercion
# Out:
# 89

# %%
ab.Hard_or_Paper.astype("category")
# Out:
# 0      P
# 1      P
# 2      P
# 3      P
# 4      P
#       ..
# 320    H
# 321    P
# 322    P
# 323    P
# 324    P
# Name: Hard_or_Paper, Length: 325, dtype: category
# Categories (2, object): ['H', 'P']

# %%
ab.Hard_or_Paper = ab.Hard_or_Paper.astype("category")

# %%
ab.dtypes
# Out:
# Title              object
# Author             object
# List Price        float64
# Amazon Price      float64
# Hard_or_Paper    category
# NumPages          float64
# Publisher          object
# Pub year          float64
# ISBN-10            object
# Height            float64
# Width             float64
# Thick             float64
# Weight_oz         float64
# dtype: object

# %%
ab.dropna().shape
# Out:
# (310, 13)

# %%
ab.isnull().sum()
# Out:
# Title            0
# Author           1
# List Price       1
# Amazon Price     0
# Hard_or_Paper    0
# NumPages         2
# Publisher        1
# Pub year         1
# ISBN-10          0
# Height           4
# Width            5
# Thick            1
# Weight_oz        9
# dtype: int64

# %%
# chaining methods! ya cul
ab.dropna().isnull().sum()
# Out:
# Title            0
# Author           0
# List Price       0
# Amazon Price     0
# Hard_or_Paper    0
# NumPages         0
# Publisher        0
# Pub year         0
# ISBN-10          0
# Height           0
# Width            0
# Thick            0
# Weight_oz        0
# dtype: int64

# %%
#ab.dropna(inplace=True)
ab = ab.dropna()

# %%
ab['Pub year'] = ab['Pub year'].astype(int)
ab
# Out:
# /tmp/ipykernel_203/1078008371.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ab['Pub year'] = ab['Pub year'].astype(int)
#                                                  Title               Author  \
# 0    1,001 Facts that Will Scare the S#*t Out of Yo...          Cary McNeal
# 1    21: Bringing Down the House - Movie Tie-In: Th...          Ben Mezrich
# 2         100 Best-Loved Poems (Dover Thrift Editions)                Smith
# 3              1421: The Year China Discovered America        Gavin Menzies
# 4      1493: Uncovering the New World Columbus Created      Charles C. Mann
# ..                                                 ...                  ...
# ...

# %%
ab.dtypes
# Out:
# Title              object
# Author             object
# List Price        float64
# Amazon Price      float64
# Hard_or_Paper    category
# NumPages          float64
# Publisher          object
# Pub year            int64
# ISBN-10            object
# Height            float64
# Width             float64
# Thick             float64
# Weight_oz         float64
# dtype: object

# %%
ab.groupby("Hard_or_Paper").NumPages.mean()
# Out:
# Hard_or_Paper
# H    321.128205
# P    333.754310
# Name: NumPages, dtype: float64

# %%
ab.groupby("Hard_or_Paper").NumPages.sum()
# Out:
# Hard_or_Paper
# H    25048.0
# P    77431.0
# Name: NumPages, dtype: float64

# %%
ab.groupby("Hard_or_Paper").NumPages.count()#/.size()
# Out:
# Hard_or_Paper
# H     78
# P    232
# Name: NumPages, dtype: int64

# %%
ab.groupby("Hard_or_Paper").NumPages.max()
# Out:
# Hard_or_Paper
# H    880.0
# P    896.0
# Name: NumPages, dtype: float64

# %%
ab.groupby("Hard_or_Paper").NumPages.quantile(.04)
# Out:
# Hard_or_Paper
# H     33.76
# P    128.00
# Name: NumPages, dtype: float64

# %%
ab[['NumPages', 'List Price', 'Amazon Price']].groupby("Hard_or_Paper").mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 ab[['NumPages', 'List Price', 'Amazon Price']].groupby("Hard_or_Paper").mean()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:8402, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8399     raise TypeError("You have to supply one of 'by' and 'level'")
#    8400 axis = self._get_axis_number(axis)
# -> 8402 return DataFrameGroupBy(
#    8403     obj=self,
#    8404     keys=by,
#    8405     axis=axis,
#    8406     level=level,
#    8407     as_index=as_index,
#    8408     sort=sort,
#    8409     group_keys=group_keys,
#    8410     squeeze=squeeze,
#    8411     observed=observed,
#    8412     dropna=dropna,
#    8413 )
#
# ...

# %%
ab[['NumPages', 'List Price', 'Amazon Price', "Hard_or_Paper"]].groupby("Hard_or_Paper").mean()
# Out:
#                  NumPages  List Price  Amazon Price
# Hard_or_Paper
# H              321.128205   20.203462     12.962821
# P              333.754310   17.171681     12.461509

# %%
ab['Publisher'].value_counts()
# Out:
# Vintage                     37
# Grand Central Publishing    10
# Washington Square Press      7
# Mariner Books                7
# Harper Paperbacks            7
#                             ..
# Warner Books                 1
# Wm. B. Eerdmans              1
# North Atlantic Books         1
# Wolfgang Publications        1
# St Martin's Griffin          1
# Name: Publisher, Length: 153, dtype: int64

# %%
ab.head()
# Out:
#                                                Title           Author  \
# 0  1,001 Facts that Will Scare the S#*t Out of Yo...      Cary McNeal
# 1  21: Bringing Down the House - Movie Tie-In: Th...      Ben Mezrich
# 2       100 Best-Loved Poems (Dover Thrift Editions)            Smith
# 3            1421: The Year China Discovered America    Gavin Menzies
# 4    1493: Uncovering the New World Columbus Created  Charles C. Mann
#
#    List Price  Amazon Price Hard_or_Paper  NumPages           Publisher  \
# 0       12.95          5.18             P     304.0         Adams Media
# 1       15.00         10.20             P     273.0          Free Press
# 2        1.50          1.50             P      96.0  Dover Publications
# 3       15.99         10.87             P     672.0    Harper Perennial
# 4       30.50         16.77             P     720.0               Knopf
#
#    Pub year     ISBN-10  Height  Width  Thick  Weight_oz
# ...

# %%
ab[0:5] # ab[:5]
# Out:
#                                                Title           Author  \
# 0  1,001 Facts that Will Scare the S#*t Out of Yo...      Cary McNeal
# 1  21: Bringing Down the House - Movie Tie-In: Th...      Ben Mezrich
# 2       100 Best-Loved Poems (Dover Thrift Editions)            Smith
# 3            1421: The Year China Discovered America    Gavin Menzies
# 4    1493: Uncovering the New World Columbus Created  Charles C. Mann
#
#    List Price  Amazon Price Hard_or_Paper  NumPages           Publisher  \
# 0       12.95          5.18             P     304.0         Adams Media
# 1       15.00         10.20             P     273.0          Free Press
# 2        1.50          1.50             P      96.0  Dover Publications
# 3       15.99         10.87             P     672.0    Harper Perennial
# 4       30.50         16.77             P     720.0               Knopf
#
#    Pub year     ISBN-10  Height  Width  Thick  Weight_oz
# ...

# %%
ab.loc[:5, ['NumPages','Publisher']]
# Out:
#    NumPages           Publisher
# 0     304.0         Adams Media
# 1     273.0          Free Press
# 2      96.0  Dover Publications
# 3     672.0    Harper Perennial
# 4     720.0               Knopf
# 5     460.0               Knopf

# %%
ab.iloc[[2,6,8,11], [0,3]]
# Out:
#                                                 Title  Amazon Price
# 2        100 Best-Loved Poems (Dover Thrift Editions)          1.50
# 6   A Christmas Carol and Other Christmas Writings...         13.46
# 9                                  A Farewell To Arms         19.80
# 12  A Guide to the Good Life: The Ancient Art of S...         13.57

# %%
ab.iloc[10:-290, [0,3]]
# Out:
#                                                 Title  Amazon Price
# 11          A Game of Thrones: A song of fire and ice         10.46
# 12  A Guide to the Good Life: The Ancient Art of S...         13.57
# 13  A Hammock Beneath the Mangoes: Stories from La...         14.60
# 14  A Holocaust Reader: Responses to the Nazi Exte...         37.95
# 15                               A Light in the Attic         11.58
# 16      A Midsummer Night's dream No Fear Shakespeare          3.99
# 17                                    A Painted House         10.20
# 18                                A Raisin In The Sun          5.87
# 19                                A Raisin in the Sun         10.85
# 20                                      A Small Place         10.40

# %%
# boolean selection
ab[ab['Hard_or_Paper']=='P']
# Out:
#                                                  Title               Author  \
# 0    1,001 Facts that Will Scare the S#*t Out of Yo...          Cary McNeal
# 1    21: Bringing Down the House - Movie Tie-In: Th...          Ben Mezrich
# 2         100 Best-Loved Poems (Dover Thrift Editions)                Smith
# 3              1421: The Year China Discovered America        Gavin Menzies
# 4      1493: Uncovering the New World Columbus Created      Charles C. Mann
# ..                                                 ...                  ...
# 319                          We have never been modern         Bruno Latour
# 321                                    White Privilege  Paula S. Rothenberg
# 322                                Why I wore lipstick        Geralyn Lucas
# 323  Worlds Together, Worlds Apart: A History of th...        Robert Tignor
# 324                                  Wuthering Heights         Emily Bronte
#
#      List Price  Amazon Price Hard_or_Paper  NumPages  \
# ...

# %%
ab[ab.NumPages>300]
# Out:
#                                                  Title           Author  \
# 0    1,001 Facts that Will Scare the S#*t Out of Yo...      Cary McNeal
# 3              1421: The Year China Discovered America    Gavin Menzies
# 4      1493: Uncovering the New World Columbus Created  Charles C. Mann
# 5                       1861:  The Civil War Awakening   Adam Goodheart
# 6    A Christmas Carol and Other Christmas Writings...          Dickens
# ..                                                 ...              ...
# 316                                            Waiting           Ha Jin
# 317                                          War Trash           Ha Jin
# 318                       Water for Elephants: A Novel            Gruen
# 323  Worlds Together, Worlds Apart: A History of th...    Robert Tignor
# 324                                  Wuthering Heights     Emily Bronte
#
#      List Price  Amazon Price Hard_or_Paper  NumPages  \
# ...

# %%
ab[(ab.NumPages>400) | (ab.NumPages<50)]
# Out:
#                                                  Title              Author  \
# 3              1421: The Year China Discovered America       Gavin Menzies
# 4      1493: Uncovering the New World Columbus Created     Charles C. Mann
# 5                       1861:  The Civil War Awakening      Adam Goodheart
# 7                              A Confederacy of Dunces  John Kennedy Toole
# 10                                      A Fine Balance     Rohinton Mistry
# ..                                                 ...                 ...
# 299                                 The Woman in White      Wilkie Collins
# 306  To End All Wars: A Story of Loyalty and Rebell...     Adam Hochschild
# 308     To the End of the Land (Vintage International)            Grossman
# 314                                           Unbroken   Laura Hillenbrand
# 323  Worlds Together, Worlds Apart: A History of th...       Robert Tignor
#
#      List Price  Amazon Price Hard_or_Paper  NumPages  \
# ...

# %%
ab[(ab.NumPages>400) & (ab.Hard_or_Paper=='H')]
# Out:
#                                                  Title  \
# 5                       1861:  The Civil War Awakening
# 24   A Year with C. S. Lewis: Daily Readings from H...
# 31                                     American Psycho
# 49                                            Catch-22
# 65                                           Divergent
# 84   Game Change: Obama and the Clintons, McCain an...
# 97                                         Hope Leslie
# 104  In the Garden of Beasts: Love, Terror, and an ...
# 105  In The Plex: How Google Thinks, Works, and Sha...
# 112                                      Invisible Man
# 135            Middlemarch (Penguin Hardback Classics)
# 141                        Nathaniel Hawthorne's Tales
# 150                                        Olive Twist
# 221             The Classic Slave Narratives-paperback
# 228                                  The Da Vinci Code
# 276                                   The Power of Six
# ...

# %%
ab['list price dollars int'] = ab['List Price'].astype(int) 
ab
# Out:
# /tmp/ipykernel_203/3689582331.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ab['list price dollars int'] = ab['List Price'].astype(int)
#                                                  Title               Author  \
# 0    1,001 Facts that Will Scare the S#*t Out of Yo...          Cary McNeal
# 1    21: Bringing Down the House - Movie Tie-In: Th...          Ben Mezrich
# 2         100 Best-Loved Poems (Dover Thrift Editions)                Smith
# 3              1421: The Year China Discovered America        Gavin Menzies
# 4      1493: Uncovering the New World Columbus Created      Charles C. Mann
# ..                                                 ...                  ...
# ...

# %%
ab.sort_values(["Pub year", "NumPages"], ascending=False)
# Out:
#                                                Title              Author  \
# 135          Middlemarch (Penguin Hardback Classics)               Eliot
# 257    The Invisible Bridge (Vintage Contemporaries)            Orringer
# 4    1493: Uncovering the New World Columbus Created     Charles C. Mann
# 11         A Game of Thrones: A song of fire and ice  George R.R. Martin
# 85                                   Game of Thrones              Martin
# ..                                               ...                 ...
# 96                                        Hop on Pop               Seuss
# 126                                Lord of the Flies     William Golding
# 220                               The Cat in the Hat               Seuss
# 138    Modern Man in Search of a Soul (Harvest Book)           C.G. Jung
# 291                           The Story of Ferdinand          Munro Leaf
#
#      List Price  Amazon Price Hard_or_Paper  NumPages  \
# ...
