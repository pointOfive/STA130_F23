# %% [markdown]
# # Data Wrangling
#
# Possible Data Sets
# - `amazonbooks.csv` (Let's start with this one!)
# - `coffee_ratings.csv`
# - `avatar.csv`
# - `oly2countries.csv`
# - `titanic.csv`

# %%
import pandas

# %%
pandas.read_csv('amazonbooks.csv', encoding="ISO-8859-1") # "utf-8" is the default
# file doesnt load without passing `parameter=argument` `encoding="ISO-8859-1"` to .read_csv()
# Out:
#                                                  Title               Author  \
# 0    1,001 Facts that Will Scare the S#*t Out of Yo...          Cary McNeal
# 1    21: Bringing Down the House - Movie Tie-In: Th...          Ben Mezrich
# 2         100 Best-Loved Poems (Dover Thrift Editions)                Smith
# 3              1421: The Year China Discovered America        Gavin Menzies
# 4      1493: Uncovering the New World Columbus Created      Charles C. Mann
# ..                                                 ...                  ...
# 320                            Where the Sidewalk Ends     Shel Silverstein
# 321                                    White Privilege  Paula S. Rothenberg
# 322                                Why I wore lipstick        Geralyn Lucas
# 323  Worlds Together, Worlds Apart: A History of th...        Robert Tignor
# 324                                  Wuthering Heights         Emily Bronte
#
#      List Price  Amazon Price Hard_or_Paper  NumPages               Publisher  \
# 0         12.95          5.18             P     304.0             Adams Media
# 1         15.00         10.20             P     273.0              Free Press
# 2          1.50          1.50             P      96.0      Dover Publications
# 3         15.99         10.87             P     672.0        Harper Perennial
# 4         30.50         16.77             P     720.0                   Knopf
# ..          ...           ...           ...       ...                     ...
# 320       18.99         12.24             H     192.0           HarperCollins
# 321       27.55         27.55             P     160.0        Worth Publishers
# 322       12.95          5.18             P     224.0     St Martin's Griffin
# 323       97.50         97.50             P     480.0  W. W. Norton & Company
# 324       16.99          4.95             P     344.0              CreatSpace
#
#      Pub year     ISBN-10  Height  Width  Thick  Weight_oz
# 0      2010.0  1605506249     7.8    5.5    0.8       11.2
# 1      2008.0  1416564195     8.4    5.5    0.7        7.2
# 2      1995.0   486285537     8.3    5.2    0.3        4.0
# 3      2008.0    61564893     8.8    6.0    1.6       28.8
# 4      2011.0   307265722     8.0    5.2    1.4       22.4
# ..        ...         ...     ...    ...    ...        ...
# 320    2004.0    60572345     9.3    6.6    1.1       24.0
# 321    2011.0  1429233443     9.1    6.1    0.7        8.0
# 322    2005.0  031233446X     8.0    5.4    0.7        6.4
# 323    2010.0   393934942    10.7    8.9    0.9       14.4
# 324    2011.0  1463533411     7.8    5.1    1.0       16.0
#
# [325 rows x 13 columns]

# %%
pd.read_csv('amazonbooks.csv', encoding="ISO-8859-1")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 pd.read_csv('amazonbooks.csv', encoding="ISO-8859-1")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd # This alias is the standard way to use import/use/call pandas stuff

# %%
pd.read_csv('amazonbooks.csv', encoding="ISO-8859-1")
# Out:
#                                                  Title               Author  \
# 0    1,001 Facts that Will Scare the S#*t Out of Yo...          Cary McNeal
# 1    21: Bringing Down the House - Movie Tie-In: Th...          Ben Mezrich
# 2         100 Best-Loved Poems (Dover Thrift Editions)                Smith
# 3              1421: The Year China Discovered America        Gavin Menzies
# 4      1493: Uncovering the New World Columbus Created      Charles C. Mann
# ..                                                 ...                  ...
# 320                            Where the Sidewalk Ends     Shel Silverstein
# 321                                    White Privilege  Paula S. Rothenberg
# 322                                Why I wore lipstick        Geralyn Lucas
# 323  Worlds Together, Worlds Apart: A History of th...        Robert Tignor
# 324                                  Wuthering Heights         Emily Bronte
#
#      List Price  Amazon Price Hard_or_Paper  NumPages               Publisher  \
# 0         12.95          5.18             P     304.0             Adams Media
# 1         15.00         10.20             P     273.0              Free Press
# 2          1.50          1.50             P      96.0      Dover Publications
# 3         15.99         10.87             P     672.0        Harper Perennial
# 4         30.50         16.77             P     720.0                   Knopf
# ..          ...           ...           ...       ...                     ...
# 320       18.99         12.24             H     192.0           HarperCollins
# 321       27.55         27.55             P     160.0        Worth Publishers
# 322       12.95          5.18             P     224.0     St Martin's Griffin
# 323       97.50         97.50             P     480.0  W. W. Norton & Company
# 324       16.99          4.95             P     344.0              CreatSpace
#
#      Pub year     ISBN-10  Height  Width  Thick  Weight_oz
# 0      2010.0  1605506249     7.8    5.5    0.8       11.2
# 1      2008.0  1416564195     8.4    5.5    0.7        7.2
# 2      1995.0   486285537     8.3    5.2    0.3        4.0
# 3      2008.0    61564893     8.8    6.0    1.6       28.8
# 4      2011.0   307265722     8.0    5.2    1.4       22.4
# ..        ...         ...     ...    ...    ...        ...
# 320    2004.0    60572345     9.3    6.6    1.1       24.0
# 321    2011.0  1429233443     9.1    6.1    0.7        8.0
# 322    2005.0  031233446X     8.0    5.4    0.7        6.4
# 323    2010.0   393934942    10.7    8.9    0.9       14.4
# 324    2011.0  1463533411     7.8    5.1    1.0       16.0
#
# [325 rows x 13 columns]

# %%
amazonbooks = pd.read_csv('amazonbooks.csv', encoding="ISO-8859-1")

# %%
type(amazonbooks)
# Out:
# pandas.core.frame.DataFrame

# %%
amazonbooks.dtypes
# 3: int
# 3.14: float / float64
# Out:
# Title             object
# Author            object
# List Price       float64
# Amazon Price     float64
# Hard_or_Paper     object
# NumPages         float64
# Publisher         object
# Pub year         float64
# ISBN-10           object
# Height           float64
# Width            float64
# Thick            float64
# Weight_oz        float64
# dtype: object

# %%
amazonbooks
# Out:
#                                                  Title               Author  \
# 0    1,001 Facts that Will Scare the S#*t Out of Yo...          Cary McNeal
# 1    21: Bringing Down the House - Movie Tie-In: Th...          Ben Mezrich
# 2         100 Best-Loved Poems (Dover Thrift Editions)                Smith
# 3              1421: The Year China Discovered America        Gavin Menzies
# 4      1493: Uncovering the New World Columbus Created      Charles C. Mann
# ..                                                 ...                  ...
# 320                            Where the Sidewalk Ends     Shel Silverstein
# 321                                    White Privilege  Paula S. Rothenberg
# 322                                Why I wore lipstick        Geralyn Lucas
# 323  Worlds Together, Worlds Apart: A History of th...        Robert Tignor
# 324                                  Wuthering Heights         Emily Bronte
#
#      List Price  Amazon Price Hard_or_Paper  NumPages               Publisher  \
# 0         12.95          5.18             P     304.0             Adams Media
# 1         15.00         10.20             P     273.0              Free Press
# 2          1.50          1.50             P      96.0      Dover Publications
# 3         15.99         10.87             P     672.0        Harper Perennial
# 4         30.50         16.77             P     720.0                   Knopf
# ..          ...           ...           ...       ...                     ...
# 320       18.99         12.24             H     192.0           HarperCollins
# 321       27.55         27.55             P     160.0        Worth Publishers
# 322       12.95          5.18             P     224.0     St Martin's Griffin
# 323       97.50         97.50             P     480.0  W. W. Norton & Company
# 324       16.99          4.95             P     344.0              CreatSpace
#
#      Pub year     ISBN-10  Height  Width  Thick  Weight_oz
# 0      2010.0  1605506249     7.8    5.5    0.8       11.2
# 1      2008.0  1416564195     8.4    5.5    0.7        7.2
# 2      1995.0   486285537     8.3    5.2    0.3        4.0
# 3      2008.0    61564893     8.8    6.0    1.6       28.8
# 4      2011.0   307265722     8.0    5.2    1.4       22.4
# ..        ...         ...     ...    ...    ...        ...
# 320    2004.0    60572345     9.3    6.6    1.1       24.0
# 321    2011.0  1429233443     9.1    6.1    0.7        8.0
# 322    2005.0  031233446X     8.0    5.4    0.7        6.4
# 323    2010.0   393934942    10.7    8.9    0.9       14.4
# 324    2011.0  1463533411     7.8    5.1    1.0       16.0
#
# [325 rows x 13 columns]

# %%
amazonbooks.describe()
# Out:
#        List Price  Amazon Price    NumPages     Pub year      Height  \
# count  324.000000    325.000000  323.000000   324.000000  321.000000
# mean    18.579753     13.333846  335.857585  2002.206790    8.163240
# std     14.252829     13.727679  161.984389    10.629002    0.918739
# min      1.500000      0.770000   24.000000  1936.000000    5.100000
# 25%     13.950000      8.600000  208.000000  1998.000000    7.900000
# 50%     15.000000     10.200000  320.000000  2005.000000    8.100000
# 75%     19.950000     13.130000  416.000000  2010.000000    8.500000
# max    139.950000    139.950000  896.000000  2011.000000   12.100000
#
#             Width       Thick   Weight_oz
# count  320.000000  324.000000  316.000000
# mean     5.585000    0.907716   12.487975
# std      0.874057    0.368625    6.644648
# min      4.100000    0.100000    1.200000
# 25%      5.200000    0.600000    7.800000
# 50%      5.400000    0.900000   11.200000
# 75%      5.900000    1.100000   16.000000
# max      9.500000    2.100000   35.200000

# %%
amazonbooks.isnull()
# Out:
#      Title  Author  List Price  Amazon Price  Hard_or_Paper  NumPages  \
# 0    False   False       False         False          False     False
# 1    False   False       False         False          False     False
# 2    False   False       False         False          False     False
# 3    False   False       False         False          False     False
# 4    False   False       False         False          False     False
# ..     ...     ...         ...           ...            ...       ...
# 320  False   False       False         False          False     False
# 321  False   False       False         False          False     False
# 322  False   False       False         False          False     False
# 323  False   False       False         False          False     False
# 324  False   False       False         False          False     False
#
#      Publisher  Pub year  ISBN-10  Height  Width  Thick  Weight_oz
# 0        False     False    False   False  False  False      False
# 1        False     False    False   False  False  False      False
# 2        False     False    False   False  False  False      False
# 3        False     False    False   False  False  False      False
# 4        False     False    False   False  False  False      False
# ..         ...       ...      ...     ...    ...    ...        ...
# 320      False     False    False   False  False  False      False
# 321      False     False    False   False  False  False      False
# 322      False     False    False   False  False  False      False
# 323      False     False    False   False  False  False      False
# 324      False     False    False   False  False  False      False
#
# [325 rows x 13 columns]

# %%
# True=1 and False=0 coercion
amazonbooks.isnull().sum() # axis=0 is the default param=arg to the .sum() function
# Out:
# Title            0
# Author           1
# List Price       1
# Amazon Price     0
# Hard_or_Paper    0
# NumPages         2
# Publisher        1
# Pub year         1
# ISBN-10          0
# Height           4
# Width            5
# Thick            1
# Weight_oz        9
# dtype: int64

# %%
amazonbooks.head()
# Out:
#                                                Title           Author  \
# 0  1,001 Facts that Will Scare the S#*t Out of Yo...      Cary McNeal
# 1  21: Bringing Down the House - Movie Tie-In: Th...      Ben Mezrich
# 2       100 Best-Loved Poems (Dover Thrift Editions)            Smith
# 3            1421: The Year China Discovered America    Gavin Menzies
# 4    1493: Uncovering the New World Columbus Created  Charles C. Mann
#
#    List Price  Amazon Price Hard_or_Paper  NumPages           Publisher  \
# 0       12.95          5.18             P     304.0         Adams Media
# 1       15.00         10.20             P     273.0          Free Press
# 2        1.50          1.50             P      96.0  Dover Publications
# 3       15.99         10.87             P     672.0    Harper Perennial
# 4       30.50         16.77             P     720.0               Knopf
#
#    Pub year     ISBN-10  Height  Width  Thick  Weight_oz
# 0    2010.0  1605506249     7.8    5.5    0.8       11.2
# 1    2008.0  1416564195     8.4    5.5    0.7        7.2
# 2    1995.0   486285537     8.3    5.2    0.3        4.0
# 3    2008.0    61564893     8.8    6.0    1.6       28.8
# 4    2011.0   307265722     8.0    5.2    1.4       22.4

# %%
amazonbooks.iloc[:5,:] # amazonbooks.iloc[0:5,0:13]
# Out:
#                                                Title           Author  \
# 0  1,001 Facts that Will Scare the S#*t Out of Yo...      Cary McNeal
# 1  21: Bringing Down the House - Movie Tie-In: Th...      Ben Mezrich
# 2       100 Best-Loved Poems (Dover Thrift Editions)            Smith
# 3            1421: The Year China Discovered America    Gavin Menzies
# 4    1493: Uncovering the New World Columbus Created  Charles C. Mann
#
#    List Price  Amazon Price Hard_or_Paper  NumPages           Publisher  \
# 0       12.95          5.18             P     304.0         Adams Media
# 1       15.00         10.20             P     273.0          Free Press
# 2        1.50          1.50             P      96.0  Dover Publications
# 3       15.99         10.87             P     672.0    Harper Perennial
# 4       30.50         16.77             P     720.0               Knopf
#
#    Pub year     ISBN-10  Height  Width  Thick  Weight_oz
# 0    2010.0  1605506249     7.8    5.5    0.8       11.2
# 1    2008.0  1416564195     8.4    5.5    0.7        7.2
# 2    1995.0   486285537     8.3    5.2    0.3        4.0
# 3    2008.0    61564893     8.8    6.0    1.6       28.8
# 4    2011.0   307265722     8.0    5.2    1.4       22.4

# %%
amazonbooks.isnull().sum(axis=1)>1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 320    False
# 321    False
# 322    False
# 323    False
# 324    False
# Length: 325, dtype: bool

# %%
# breaks!
amazonbooks.iloc[ amazonbooks.isnull().sum(axis=1)>1 ,:]
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 amazonbooks.iloc[ amazonbooks.isnull().sum(axis=1)>1 ,:]
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1563, in _iLocIndexer._getitem_tuple(self, tup)
#    1561 def _getitem_tuple(self, tup: tuple):
# -> 1563     tup = self._validate_tuple_indexer(tup)
#    1564     with suppress(IndexingError):
#    1565         return self._getitem_lowerdim(tup)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:873, in _LocationIndexer._validate_tuple_indexer(self, key)
#     871 for i, k in enumerate(key):
#     872     try:
# --> 873         self._validate_key(k, i)
#     874     except ValueError as err:
#     875         raise ValueError(
#     876             "Location based indexing can only have "
#     877             f"[{self._valid_types}] types"
#     878         ) from err
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1452, in _iLocIndexer._validate_key(self, key, axis)
#    1450 if hasattr(key, "index") and isinstance(key.index, Index):
#    1451     if key.index.inferred_type == "integer":
# -> 1452         raise NotImplementedError(
#    1453             "iLocation based boolean "
#    1454             "indexing on an integer type "
#    1455             "is not available"
#    1456         )
#    1457     raise ValueError(
#    1458         "iLocation based boolean indexing cannot use "
#    1459         "an indexable as a mask"
#    1460     )
#    1461 return
#
# NotImplementedError: iLocation based boolean indexing on an integer type is not available

# %%
amazonbooks[amazonbooks.isnull().sum(axis=1)>1]
# Out:
#                                                  Title  \
# 8                                 A Dance With Dragons
# 94   Heroes of Olympus, The, Book Two: The Son of N...
# 102                                          Ice bound
# 107                                        Inheritance
# 165                                             Prized
# 184                   Security Analysis: Sixth Edition
# 259  The John Deere Two-Cylinder Tractor Encycloped...
#
#                               Author  List Price  Amazon Price Hard_or_Paper  \
# 8                  Martin RR, George       35.00         18.81             H
# 94                     Riordan, Rick       19.99         10.75             H
# 102  Maryanne Vollers, Jerri Nielsen       14.95          5.98             P
# 107             Paolini, Christopher       27.99         13.98             H
# 165               O'Brien, Caragh M.       16.99         10.79             H
# 184                  Benjamin Graham       75.00         39.45             H
# 259                    Don Macmillan       39.95         23.79             H
#
#      NumPages                      Publisher  Pub year     ISBN-10  Height  \
# 8         NaN                         Bantam    2011.0   553801473     9.6
# 94      544.0               Hyperion Book CH    2011.0  1423140591     NaN
# 102     377.0                            NaN       NaN   786886994     8.3
# 107     704.0  Knopf Books for Young Readers    2011.0   375856110     NaN
# 165     368.0            Roaring Brook Press    2011.0  1596435704     NaN
# 184     700.0                    ÊMcGraw-Hil    2008.0    71592539     9.5
# 259     256.0                 Voyageur Press    2007.0  140003437X     NaN
#
#      Width  Thick  Weight_oz
# 8      6.5    2.1        NaN
# 94     NaN    1.8       25.6
# 102    5.3    1.0       12.8
# 107    NaN    2.1        NaN
# 165    NaN    1.2        NaN
# 184    6.5    NaN        NaN
# 259    NaN    1.0        NaN

# %%
amazonbooks[amazonbooks.isnull().sum(axis=1)>0]
# Out:
#                                                  Title  \
# 8                                 A Dance With Dragons
# 76                                              Fences
# 94   Heroes of Olympus, The, Book Two: The Son of N...
# 102                                          Ice bound
# 107                                        Inheritance
# 165                                             Prized
# 166                Psychology Ninth Edition in Modules
# 168                    Rainbow Green Live-Food Cuisine
# 169  Raw Food, Real World: 100 Recipes to Get the Glow
# 184                   Security Analysis: Sixth Edition
# 204                                  The 80 10 10 Diet
# 210                 The Audacity to Win: How Obama Won
# 259  The John Deere Two-Cylinder Tractor Encycloped...
# 272                            The Old Man and The Sea
# 298                     The Ultimate Guide to Tractors
#
#                               Author  List Price  Amazon Price Hard_or_Paper  \
# 8                  Martin RR, George       35.00         18.81             H
# 76                     August Wislon       21.10         16.46             H
# 94                     Riordan, Rick       19.99         10.75             H
# 102  Maryanne Vollers, Jerri Nielsen       14.95          5.98             P
# 107             Paolini, Christopher       27.99         13.98             H
# 165               O'Brien, Caragh M.       16.99         10.79             H
# 166                   David G. Myers       98.95         98.95             H
# 168                          Cousens       19.73         15.68             H
# 169               Kenny & Meingallis       37.50         25.00             H
# 184                  Benjamin Graham       75.00         39.45             H
# 204                           Graham         NaN        118.21             P
# 210                              NaN       16.00          6.40             P
# 259                    Don Macmillan       39.95         23.79             H
# 272                Earnest Hemingway       12.00          9.09             P
# 298                  Jim Glastonbury       24.99         17.99             H
#
#      NumPages                      Publisher  Pub year     ISBN-10  Height  \
# 8         NaN                         Bantam    2011.0   553801473     9.6
# 76        NaN            Perfection Leraning    1986.0   780707508     9.0
# 94      544.0               Hyperion Book CH    2011.0  1423140591     NaN
# 102     377.0                            NaN       NaN   786886994     8.3
# 107     704.0  Knopf Books for Young Readers    2011.0   375856110     NaN
# 165     368.0            Roaring Brook Press    2011.0  1596435704     NaN
# 166     778.0               Worth Publishers    2009.0  1429238240    11.3
# 168     544.0           North Atlantic Books    2003.0  1556434650     9.0
# 169     384.0       William Morrow Cookbooks    2005.0    60793554     9.1
# 184     700.0                    ÊMcGraw-Hil    2008.0    71592539     9.5
# 204     340.0               foodnsport Press    2006.0  1893831248     8.9
# 210     432.0                        Penguin    2010.0   143118080     8.4
# 259     256.0                 Voyageur Press    2007.0  140003437X     NaN
# 272     128.0                       Scribner    1995.0   684801221     5.2
# 298     448.0                Chartwell Books    2011.0   785828400    11.5
#
#      Width  Thick  Weight_oz
# 8      6.5    2.1        NaN
# 76     6.0    1.0       22.4
# 94     NaN    1.8       25.6
# 102    5.3    1.0       12.8
# 107    NaN    2.1        NaN
# 165    NaN    1.2        NaN
# 166    9.5    1.5        NaN
# 168    7.0    1.0        NaN
# 169    7.3    1.4        NaN
# 184    6.5    NaN        NaN
# 204    6.0    0.8       16.0
# 210    5.5    1.0       12.8
# 259    NaN    1.0        NaN
# 272    NaN    0.8        4.0
# 298    6.0    1.5        NaN

# %%
amazonbooks[amazonbooks.isnull().sum(axis=1)==0]
# Out:
#                                                  Title               Author  \
# 0    1,001 Facts that Will Scare the S#*t Out of Yo...          Cary McNeal
# 1    21: Bringing Down the House - Movie Tie-In: Th...          Ben Mezrich
# 2         100 Best-Loved Poems (Dover Thrift Editions)                Smith
# 3              1421: The Year China Discovered America        Gavin Menzies
# 4      1493: Uncovering the New World Columbus Created      Charles C. Mann
# ..                                                 ...                  ...
# 320                            Where the Sidewalk Ends     Shel Silverstein
# 321                                    White Privilege  Paula S. Rothenberg
# 322                                Why I wore lipstick        Geralyn Lucas
# 323  Worlds Together, Worlds Apart: A History of th...        Robert Tignor
# 324                                  Wuthering Heights         Emily Bronte
#
#      List Price  Amazon Price Hard_or_Paper  NumPages               Publisher  \
# 0         12.95          5.18             P     304.0             Adams Media
# 1         15.00         10.20             P     273.0              Free Press
# 2          1.50          1.50             P      96.0      Dover Publications
# 3         15.99         10.87             P     672.0        Harper Perennial
# 4         30.50         16.77             P     720.0                   Knopf
# ..          ...           ...           ...       ...                     ...
# 320       18.99         12.24             H     192.0           HarperCollins
# 321       27.55         27.55             P     160.0        Worth Publishers
# 322       12.95          5.18             P     224.0     St Martin's Griffin
# 323       97.50         97.50             P     480.0  W. W. Norton & Company
# 324       16.99          4.95             P     344.0              CreatSpace
#
#      Pub year     ISBN-10  Height  Width  Thick  Weight_oz
# 0      2010.0  1605506249     7.8    5.5    0.8       11.2
# 1      2008.0  1416564195     8.4    5.5    0.7        7.2
# 2      1995.0   486285537     8.3    5.2    0.3        4.0
# 3      2008.0    61564893     8.8    6.0    1.6       28.8
# 4      2011.0   307265722     8.0    5.2    1.4       22.4
# ..        ...         ...     ...    ...    ...        ...
# 320    2004.0    60572345     9.3    6.6    1.1       24.0
# 321    2011.0  1429233443     9.1    6.1    0.7        8.0
# 322    2005.0  031233446X     8.0    5.4    0.7        6.4
# 323    2010.0   393934942    10.7    8.9    0.9       14.4
# 324    2011.0  1463533411     7.8    5.1    1.0       16.0
#
# [310 rows x 13 columns]

# %% [markdown]
# ## SQL: structured query language
# - `select` [columns] (`.loc[:,]` which supports "boolean indexing" unlike `.iloc[]`)
# - `where` [rows] (`[]` or `.loc[:,]` but not `.iloc[]`]
# - `groupby` then "aggregation function"

# %%
amazonbooks.select('Author')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 amazonbooks.select('Author')
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'select'

# %%
# tuple (1,2,3) # immutable
# list [1,2,3] # mutable
amazonbooks.loc[amazonbooks.isnull().sum(axis=1)>0, ('Author', 'Title')]
# Out:
#                               Author  \
# 8                  Martin RR, George
# 76                     August Wislon
# 94                     Riordan, Rick
# 102  Maryanne Vollers, Jerri Nielsen
# 107             Paolini, Christopher
# 165               O'Brien, Caragh M.
# 166                   David G. Myers
# 168                          Cousens
# 169               Kenny & Meingallis
# 184                  Benjamin Graham
# 204                           Graham
# 210                              NaN
# 259                    Don Macmillan
# 272                Earnest Hemingway
# 298                  Jim Glastonbury
#
#                                                  Title
# 8                                 A Dance With Dragons
# 76                                              Fences
# 94   Heroes of Olympus, The, Book Two: The Son of N...
# 102                                          Ice bound
# 107                                        Inheritance
# 165                                             Prized
# 166                Psychology Ninth Edition in Modules
# 168                    Rainbow Green Live-Food Cuisine
# 169  Raw Food, Real World: 100 Recipes to Get the Glow
# 184                   Security Analysis: Sixth Edition
# 204                                  The 80 10 10 Diet
# 210                 The Audacity to Win: How Obama Won
# 259  The John Deere Two-Cylinder Tractor Encycloped...
# 272                            The Old Man and The Sea
# 298                     The Ultimate Guide to Tractors

# %%
# amazonbooks.filter(amazonbooks.isnull().sum(axis=1)>0) # WRONG -- not using this one right...
# amazonbooks.where(amazonbooks.isnull().sum(axis=1)>0) # WRONG AGAIN!! 
# `.where()` is actually a cool useful function to replace specific values
# e.g., like missing values!
# ... hmm ... actually ...
# Maybe the best way to fill in missing values would be the `.fillna()` function

# %%
amazonbooks.groupby('Publisher')

# %%
amazonbooks.groupby('Publisher').count()
# Out:
#                               Title  Author  List Price  Amazon Price  \
# Publisher
# 1st International ed edition      1       1           1             1
# Adams Media                       1       1           1             1
# Akashic Books                     1       1           1             1
# Aladdin                           1       1           1             1
# Albert Whitman & Company          1       1           1             1
# ...                             ...     ...         ...           ...
# Worth Publishers                  2       2           2             2
# Yale University Press             1       1           1             1
# Yearling                          1       1           1             1
# foodnsport Press                  1       1           0             1
# ÊMcGraw-Hil                       1       1           1             1
#
#                               Hard_or_Paper  NumPages  Pub year  ISBN-10  \
# Publisher
# 1st International ed edition              1         1         1        1
# Adams Media                               1         1         1        1
# Akashic Books                             1         1         1        1
# Aladdin                                   1         1         1        1
# Albert Whitman & Company                  1         1         1        1
# ...                                     ...       ...       ...      ...
# Worth Publishers                          2         2         2        2
# Yale University Press                     1         1         1        1
# Yearling                                  1         1         1        1
# foodnsport Press                          1         1         1        1
# ÊMcGraw-Hil                               1         1         1        1
#
#                               Height  Width  Thick  Weight_oz
# Publisher
# 1st International ed edition       1      1      1          1
# Adams Media                        1      1      1          1
# Akashic Books                      1      1      1          1
# Aladdin                            1      1      1          1
# Albert Whitman & Company           1      1      1          1
# ...                              ...    ...    ...        ...
# Worth Publishers                   2      2      2          1
# Yale University Press              1      1      1          1
# Yearling                           1      1      1          1
# foodnsport Press                   1      1      1          1
# ÊMcGraw-Hil                        1      1      0          0
#
# [161 rows x 12 columns]

# %%
amazonbooks.groupby('Publisher').size()
# Out:
# Publisher
# 1st International ed edition    1
# Adams Media                     1
# Akashic Books                   1
# Aladdin                         1
# Albert Whitman & Company        1
#                                ..
# Worth Publishers                2
# Yale University Press           1
# Yearling                        1
# foodnsport Press                1
# ÊMcGraw-Hil                     1
# Length: 161, dtype: int64

# %%
amazonbooks.groupby('Publisher').size().sort_values() # default is `ascending=True`
# Out:
# Publisher
# 1st International ed edition     1
# Routledge                        1
# Roaring Brook Press              1
# Reagan Arthur Books              1
# Razorbill                        1
#                                 ..
# Harper Paperbacks                7
# Mariner Books                    7
# Bantam                           8
# Grand Central Publishing        10
# Vintage                         37
# Length: 161, dtype: int64

# %%
amazonbooks.groupby('Publisher').size().sort_values(ascending=False) # False not false or FALSE
# Out:
# Publisher
# Vintage                       37
# Grand Central Publishing      10
# Bantam                         8
# Harper Paperbacks              7
# Washington Square Press        7
#                               ..
# Free Press                     1
# Farrar, Straus, and Giroux     1
# Farrar Straus Giroux           1
# Farr, Straus and Giroux        1
# ÊMcGraw-Hil                    1
# Length: 161, dtype: int64

# %%
amazonbooks.groupby('Publisher').size().value_counts() # count_values
# Out:
# 1     112
# 2      21
# 3       9
# 4       4
# 6       4
# 7       4
# 5       4
# 8       1
# 10      1
# 37      1
# dtype: int64

# %%
amazonbooks.groupby('Pub year').size()#.value_counts()
# Out:
# Pub year
# 1936.0     1
# 1955.0     1
# 1957.0     1
# 1959.0     1
# 1963.0     2
# 1964.0     2
# 1965.0     1
# 1967.0     1
# 1976.0     1
# 1979.0     1
# 1982.0     2
# 1985.0     1
# 1986.0     1
# 1987.0     3
# 1988.0     2
# 1989.0     6
# 1990.0     5
# 1991.0     4
# 1992.0     4
# 1993.0     9
# 1994.0     5
# 1995.0     8
# 1996.0     7
# 1997.0     6
# 1998.0     7
# 1999.0    13
# 2000.0     7
# 2001.0     9
# 2002.0    12
# 2003.0    13
# 2004.0    16
# 2005.0    12
# 2006.0    19
# 2007.0    12
# 2008.0    16
# 2009.0    20
# 2010.0    40
# 2011.0    53
# dtype: int64

# %%
amazonbooks.describe()
# Out:
#        List Price  Amazon Price    NumPages     Pub year      Height  \
# count  324.000000    325.000000  323.000000   324.000000  321.000000
# mean    18.579753     13.333846  335.857585  2002.206790    8.163240
# std     14.252829     13.727679  161.984389    10.629002    0.918739
# min      1.500000      0.770000   24.000000  1936.000000    5.100000
# 25%     13.950000      8.600000  208.000000  1998.000000    7.900000
# 50%     15.000000     10.200000  320.000000  2005.000000    8.100000
# 75%     19.950000     13.130000  416.000000  2010.000000    8.500000
# max    139.950000    139.950000  896.000000  2011.000000   12.100000
#
#             Width       Thick   Weight_oz
# count  320.000000  324.000000  316.000000
# mean     5.585000    0.907716   12.487975
# std      0.874057    0.368625    6.644648
# min      4.100000    0.100000    1.200000
# 25%      5.200000    0.600000    7.800000
# 50%      5.400000    0.900000   11.200000
# 75%      5.900000    1.100000   16.000000
# max      9.500000    2.100000   35.200000

# %%
amazonbooks
# Out:
#                                                  Title               Author  \
# 0    1,001 Facts that Will Scare the S#*t Out of Yo...          Cary McNeal
# 1    21: Bringing Down the House - Movie Tie-In: Th...          Ben Mezrich
# 2         100 Best-Loved Poems (Dover Thrift Editions)                Smith
# 3              1421: The Year China Discovered America        Gavin Menzies
# 4      1493: Uncovering the New World Columbus Created      Charles C. Mann
# ..                                                 ...                  ...
# 320                            Where the Sidewalk Ends     Shel Silverstein
# 321                                    White Privilege  Paula S. Rothenberg
# 322                                Why I wore lipstick        Geralyn Lucas
# 323  Worlds Together, Worlds Apart: A History of th...        Robert Tignor
# 324                                  Wuthering Heights         Emily Bronte
#
#      List Price  Amazon Price Hard_or_Paper  NumPages               Publisher  \
# 0         12.95          5.18             P     304.0             Adams Media
# 1         15.00         10.20             P     273.0              Free Press
# 2          1.50          1.50             P      96.0      Dover Publications
# 3         15.99         10.87             P     672.0        Harper Perennial
# 4         30.50         16.77             P     720.0                   Knopf
# ..          ...           ...           ...       ...                     ...
# 320       18.99         12.24             H     192.0           HarperCollins
# 321       27.55         27.55             P     160.0        Worth Publishers
# 322       12.95          5.18             P     224.0     St Martin's Griffin
# 323       97.50         97.50             P     480.0  W. W. Norton & Company
# 324       16.99          4.95             P     344.0              CreatSpace
#
#      Pub year     ISBN-10  Height  Width  Thick  Weight_oz
# 0      2010.0  1605506249     7.8    5.5    0.8       11.2
# 1      2008.0  1416564195     8.4    5.5    0.7        7.2
# 2      1995.0   486285537     8.3    5.2    0.3        4.0
# 3      2008.0    61564893     8.8    6.0    1.6       28.8
# 4      2011.0   307265722     8.0    5.2    1.4       22.4
# ..        ...         ...     ...    ...    ...        ...
# 320    2004.0    60572345     9.3    6.6    1.1       24.0
# 321    2011.0  1429233443     9.1    6.1    0.7        8.0
# 322    2005.0  031233446X     8.0    5.4    0.7        6.4
# 323    2010.0   393934942    10.7    8.9    0.9       14.4
# 324    2011.0  1463533411     7.8    5.1    1.0       16.0
#
# [325 rows x 13 columns]

# %%
amazonbooks[("NumPages")]
# Out:
# 0      304.0
# 1      273.0
# 2       96.0
# 3      672.0
# 4      720.0
#        ...
# 320    192.0
# 321    160.0
# 322    224.0
# 323    480.0
# 324    344.0
# Name: NumPages, Length: 325, dtype: float64

# %%
amazonbooks[("NumPages")]
# Out:
# 0      304.0
# 1      273.0
# 2       96.0
# 3      672.0
# 4      720.0
#        ...
# 320    192.0
# 321    160.0
# 322    224.0
# 323    480.0
# 324    344.0
# Name: NumPages, Length: 325, dtype: float64

# %%
amazonbooks[(("NumPages"))] # tuple in a tuple () immutable
# Out:
# 0      304.0
# 1      273.0
# 2       96.0
# 3      672.0
# 4      720.0
#        ...
# 320    192.0
# 321    160.0
# 322    224.0
# 323    480.0
# 324    344.0
# Name: NumPages, Length: 325, dtype: float64

# %%
amazonbooks[[("NumPages")]] # tuple in a list [] mutable
# Out:
#      NumPages
# 0       304.0
# 1       273.0
# 2        96.0
# 3       672.0
# 4       720.0
# ..        ...
# 320     192.0
# 321     160.0
# 322     224.0
# 323     480.0
# 324     344.0
#
# [325 rows x 1 columns]

# %%
amazonbooks.NumPages # amazonbooks[("NumPages")] / amazonbooks[(("NumPages"))]
# Out:
# 0      304.0
# 1      273.0
# 2       96.0
# 3      672.0
# 4      720.0
#        ...
# 320    192.0
# 321    160.0
# 322    224.0
# 323    480.0
# 324    344.0
# Name: NumPages, Length: 325, dtype: float64

# %%
amazonbooks.NumPages > 335.857585
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 320    False
# 321    False
# 322    False
# 323     True
# 324     True
# Name: NumPages, Length: 325, dtype: bool

# %%
amazonbooks.groupby(amazonbooks.NumPages > 335.857585).size()
# Out:
# NumPages
# False    167
# True     158
# dtype: int64

# %%
amazonbooks.groupby(amazonbooks.NumPages > 335.857585).mean()
# Out:
# /tmp/ipykernel_123/1643671422.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   amazonbooks.groupby(amazonbooks.NumPages > 335.857585).mean()
#           List Price  Amazon Price    NumPages     Pub year    Height  \
# NumPages
# False      16.373713     11.921677  214.533333  2000.371257  8.025301
# True       20.926306     14.826456  462.556962  2004.159236  8.310968
#
#              Width     Thick  Weight_oz
# NumPages
# False     5.592121  0.671856   9.166061
# True      5.577419  1.158599  16.117881

# %%
amazonbooks.groupby(amazonbooks.NumPages > 335.857585).mean(numeric_only=True)
# Out:
#           List Price  Amazon Price    NumPages     Pub year    Height  \
# NumPages
# False      16.373713     11.921677  214.533333  2000.371257  8.025301
# True       20.926306     14.826456  462.556962  2004.159236  8.310968
#
#              Width     Thick  Weight_oz
# NumPages
# False     5.592121  0.671856   9.166061
# True      5.577419  1.158599  16.117881

# %%
amazonbooks[['Amazon Price']].groupby(amazonbooks.NumPages > 335.857585).mean()
# Out:
#           Amazon Price
# NumPages
# False        11.921677
# True         14.826456

# %%
# add a new column!
amazonbooks['AboveAverageNumPages'] = amazonbooks.NumPages > 335.857585

# %%
amazonbooks.groupby('AboveAverageNumPages').mean(numeric_only=True)
# Out:
#                       List Price  Amazon Price    NumPages     Pub year  \
# AboveAverageNumPages
# False                  16.373713     11.921677  214.533333  2000.371257
# True                   20.926306     14.826456  462.556962  2004.159236
#
#                         Height     Width     Thick  Weight_oz
# AboveAverageNumPages
# False                 8.025301  5.592121  0.671856   9.166061
# True                  8.310968  5.577419  1.158599  16.117881

# %%
# breaks!
amazonbooks[['Amazon Price']].groupby('AboveAverageNumPages').mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 amazonbooks[['Amazon Price']].groupby('AboveAverageNumPages').mean()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:8402, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8399     raise TypeError("You have to supply one of 'by' and 'level'")
#    8400 axis = self._get_axis_number(axis)
# -> 8402 return DataFrameGroupBy(
#    8403     obj=self,
#    8404     keys=by,
#    8405     axis=axis,
#    8406     level=level,
#    8407     as_index=as_index,
#    8408     sort=sort,
#    8409     group_keys=group_keys,
#    8410     squeeze=squeeze,
#    8411     observed=observed,
#    8412     dropna=dropna,
#    8413 )
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:965, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     962 if grouper is None:
#     963     from pandas.core.groupby.grouper import get_grouper
# --> 965     grouper, exclusions, obj = get_grouper(
#     966         obj,
#     967         keys,
#     968         axis=axis,
#     969         level=level,
#     970         sort=sort,
#     971         observed=observed,
#     972         mutated=self.mutated,
#     973         dropna=self.dropna,
#     974     )
#     976 self.obj = obj
#     977 self.axis = obj._get_axis_number(axis)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/groupby/grouper.py:888, in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     886         in_axis, level, gpr = False, gpr, None
#     887     else:
# --> 888         raise KeyError(gpr)
#     889 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     890     # Add key to exclusions
#     891     exclusions.add(gpr.key)
#
# KeyError: 'AboveAverageNumPages'

# %%
amazonbooks[['Amazon Price','AboveAverageNumPages']].groupby('AboveAverageNumPages').mean()
# Out:
#                       Amazon Price
# AboveAverageNumPages
# False                    11.921677
# True                     14.826456

# %%
amazonbooks
# Out:
#                                                  Title               Author  \
# 0    1,001 Facts that Will Scare the S#*t Out of Yo...          Cary McNeal
# 1    21: Bringing Down the House - Movie Tie-In: Th...          Ben Mezrich
# 2         100 Best-Loved Poems (Dover Thrift Editions)                Smith
# 3              1421: The Year China Discovered America        Gavin Menzies
# 4      1493: Uncovering the New World Columbus Created      Charles C. Mann
# ..                                                 ...                  ...
# 320                            Where the Sidewalk Ends     Shel Silverstein
# 321                                    White Privilege  Paula S. Rothenberg
# 322                                Why I wore lipstick        Geralyn Lucas
# 323  Worlds Together, Worlds Apart: A History of th...        Robert Tignor
# 324                                  Wuthering Heights         Emily Bronte
#
#      List Price  Amazon Price Hard_or_Paper  NumPages               Publisher  \
# 0         12.95          5.18             P     304.0             Adams Media
# 1         15.00         10.20             P     273.0              Free Press
# 2          1.50          1.50             P      96.0      Dover Publications
# 3         15.99         10.87             P     672.0        Harper Perennial
# 4         30.50         16.77             P     720.0                   Knopf
# ..          ...           ...           ...       ...                     ...
# 320       18.99         12.24             H     192.0           HarperCollins
# 321       27.55         27.55             P     160.0        Worth Publishers
# 322       12.95          5.18             P     224.0     St Martin's Griffin
# 323       97.50         97.50             P     480.0  W. W. Norton & Company
# 324       16.99          4.95             P     344.0              CreatSpace
#
#      Pub year     ISBN-10  Height  Width  Thick  Weight_oz  \
# 0      2010.0  1605506249     7.8    5.5    0.8       11.2
# 1      2008.0  1416564195     8.4    5.5    0.7        7.2
# 2      1995.0   486285537     8.3    5.2    0.3        4.0
# 3      2008.0    61564893     8.8    6.0    1.6       28.8
# 4      2011.0   307265722     8.0    5.2    1.4       22.4
# ..        ...         ...     ...    ...    ...        ...
# 320    2004.0    60572345     9.3    6.6    1.1       24.0
# 321    2011.0  1429233443     9.1    6.1    0.7        8.0
# 322    2005.0  031233446X     8.0    5.4    0.7        6.4
# 323    2010.0   393934942    10.7    8.9    0.9       14.4
# 324    2011.0  1463533411     7.8    5.1    1.0       16.0
#
#      AboveAverageNumPages
# 0                   False
# 1                   False
# 2                   False
# 3                    True
# 4                    True
# ..                    ...
# 320                 False
# 321                 False
# 322                 False
# 323                  True
# 324                  True
#
# [325 rows x 14 columns]

# %%
#amazonbooks['PricePerPage'] = amazonbooks.NumPages/amazonbooks['Amazon Price'] # oops! upside down
amazonbooks['PricePerPage'] = amazonbooks['Amazon Price']/amazonbooks.NumPages
amazonbooks[['PricePerPage','Hard_or_Paper']].groupby('Hard_or_Paper').mean()
# Out:
#                PricePerPage
# Hard_or_Paper
# H                  0.062509
# P                  0.046936

# %%
# The "standard deviation" `.std()` function measure how spread around the data mean the data is
amazonbooks[['PricePerPage','Hard_or_Paper']].groupby('Hard_or_Paper').std()
# Out:
#                PricePerPage
# Hard_or_Paper
# H                  0.059555
# P                  0.067023

# %%
amazonbooks
# Out:
#                                                  Title               Author  \
# 0    1,001 Facts that Will Scare the S#*t Out of Yo...          Cary McNeal
# 1    21: Bringing Down the House - Movie Tie-In: Th...          Ben Mezrich
# 2         100 Best-Loved Poems (Dover Thrift Editions)                Smith
# 3              1421: The Year China Discovered America        Gavin Menzies
# 4      1493: Uncovering the New World Columbus Created      Charles C. Mann
# ..                                                 ...                  ...
# 320                            Where the Sidewalk Ends     Shel Silverstein
# 321                                    White Privilege  Paula S. Rothenberg
# 322                                Why I wore lipstick        Geralyn Lucas
# 323  Worlds Together, Worlds Apart: A History of th...        Robert Tignor
# 324                                  Wuthering Heights         Emily Bronte
#
#      List Price  Amazon Price Hard_or_Paper  NumPages               Publisher  \
# 0         12.95          5.18             P     304.0             Adams Media
# 1         15.00         10.20             P     273.0              Free Press
# 2          1.50          1.50             P      96.0      Dover Publications
# 3         15.99         10.87             P     672.0        Harper Perennial
# 4         30.50         16.77             P     720.0                   Knopf
# ..          ...           ...           ...       ...                     ...
# 320       18.99         12.24             H     192.0           HarperCollins
# 321       27.55         27.55             P     160.0        Worth Publishers
# 322       12.95          5.18             P     224.0     St Martin's Griffin
# 323       97.50         97.50             P     480.0  W. W. Norton & Company
# 324       16.99          4.95             P     344.0              CreatSpace
#
#      Pub year     ISBN-10  Height  Width  Thick  Weight_oz  \
# 0      2010.0  1605506249     7.8    5.5    0.8       11.2
# 1      2008.0  1416564195     8.4    5.5    0.7        7.2
# 2      1995.0   486285537     8.3    5.2    0.3        4.0
# 3      2008.0    61564893     8.8    6.0    1.6       28.8
# 4      2011.0   307265722     8.0    5.2    1.4       22.4
# ..        ...         ...     ...    ...    ...        ...
# 320    2004.0    60572345     9.3    6.6    1.1       24.0
# 321    2011.0  1429233443     9.1    6.1    0.7        8.0
# 322    2005.0  031233446X     8.0    5.4    0.7        6.4
# 323    2010.0   393934942    10.7    8.9    0.9       14.4
# 324    2011.0  1463533411     7.8    5.1    1.0       16.0
#
#      AboveAverageNumPages  PricePerPage
# 0                   False      0.017039
# 1                   False      0.037363
# 2                   False      0.015625
# 3                    True      0.016176
# 4                    True      0.023292
# ..                    ...           ...
# 320                 False      0.063750
# 321                 False      0.172187
# 322                 False      0.023125
# 323                  True      0.203125
# 324                  True      0.014390
#
# [325 rows x 15 columns]

# %% [markdown]
# ### What we learned
#
# - boolean indexing
# - `.iloc[]` selecting based on index
# - `.loc[]` selecting with boolean indexing or columns or both
# - `[]` selecting with boolean indexing or columns but not both
# - `.groupby()` and "aggregation functions" like ~~`.count()`~~ `.size()`, `.mean()`, and `.std()`
# - adding/creating columns
# - learned about accessing columns
#     - `df.col` or `df['col']` or `df[('col')]` or `df[(('col'))]` give series
#     - `df[['col']]` gives dataframe
# - `sort_values(ascending=True)`

# %% [markdown]
# ### Forgot to mention that we also covered
# - Error handing
# - Missing values with `.isnull()`
#     - `.sum()` and `.sum(axis=1)`
#     - There's also `.mean()` and `.std()` functions like this, e.g.

# %%
import pandas as pd
amazonbooks = pd.read_csv('amazonbooks.csv', encoding="ISO-8859-1")

# %%
amazonbooks
# Out:
#                                                  Title               Author  \
# 0    1,001 Facts that Will Scare the S#*t Out of Yo...          Cary McNeal
# 1    21: Bringing Down the House - Movie Tie-In: Th...          Ben Mezrich
# 2         100 Best-Loved Poems (Dover Thrift Editions)                Smith
# 3              1421: The Year China Discovered America        Gavin Menzies
# 4      1493: Uncovering the New World Columbus Created      Charles C. Mann
# ..                                                 ...                  ...
# 320                            Where the Sidewalk Ends     Shel Silverstein
# 321                                    White Privilege  Paula S. Rothenberg
# 322                                Why I wore lipstick        Geralyn Lucas
# 323  Worlds Together, Worlds Apart: A History of th...        Robert Tignor
# 324                                  Wuthering Heights         Emily Bronte
#
#      List Price  Amazon Price Hard_or_Paper  NumPages               Publisher  \
# 0         12.95          5.18             P     304.0             Adams Media
# 1         15.00         10.20             P     273.0              Free Press
# 2          1.50          1.50             P      96.0      Dover Publications
# 3         15.99         10.87             P     672.0        Harper Perennial
# 4         30.50         16.77             P     720.0                   Knopf
# ..          ...           ...           ...       ...                     ...
# 320       18.99         12.24             H     192.0           HarperCollins
# 321       27.55         27.55             P     160.0        Worth Publishers
# 322       12.95          5.18             P     224.0     St Martin's Griffin
# 323       97.50         97.50             P     480.0  W. W. Norton & Company
# 324       16.99          4.95             P     344.0              CreatSpace
#
#      Pub year     ISBN-10  Height  Width  Thick  Weight_oz
# 0      2010.0  1605506249     7.8    5.5    0.8       11.2
# 1      2008.0  1416564195     8.4    5.5    0.7        7.2
# 2      1995.0   486285537     8.3    5.2    0.3        4.0
# 3      2008.0    61564893     8.8    6.0    1.6       28.8
# 4      2011.0   307265722     8.0    5.2    1.4       22.4
# ..        ...         ...     ...    ...    ...        ...
# 320    2004.0    60572345     9.3    6.6    1.1       24.0
# 321    2011.0  1429233443     9.1    6.1    0.7        8.0
# 322    2005.0  031233446X     8.0    5.4    0.7        6.4
# 323    2010.0   393934942    10.7    8.9    0.9       14.4
# 324    2011.0  1463533411     7.8    5.1    1.0       16.0
#
# [325 rows x 13 columns]

# %%
amazonbooks.loc[ (amazonbooks.Hard_or_Paper=='P')&(amazonbooks.NumPages<100) ,('Title','Author','List Price')]
# Out:
#                                                  Title           Author  \
# 2         100 Best-Loved Poems (Dover Thrift Editions)            Smith
# 20                                       A Small Place  Jamaica Kincaid
# 55                   Cloudy With a Chance of Meatballs     Judi Barrett
# 109  Innovation Killers: How Financial Tools Destro...      Christensen
# 147                                   Oedipus the King   E.A. Sophocles
#
#      List Price
# 2          1.50
# 20        13.00
# 55         6.99
# 109        8.95
# 147        6.95

# %%
amazonbooks.loc[ (amazonbooks.Hard_or_Paper=='P')&((amazonbooks.NumPages<50)|(amazonbooks.NumPages>600)),('Title','Author','List Price','NumPages')]
# Out:
#                                                  Title              Author  \
# 3              1421: The Year China Discovered America       Gavin Menzies
# 4      1493: Uncovering the New World Columbus Created     Charles C. Mann
# 10                                      A Fine Balance     Rohinton Mistry
# 11           A Game of Thrones: A song of fire and ice  George R.R. Martin
# 26                   Ada, or Ardor: A Family Chronicle    Vladimir Nabokov
# 32                                     Andrew Carnegie         David Nasaw
# 55                   Cloudy With a Chance of Meatballs        Judi Barrett
# 60                                   Cutting for Stone            Verghese
# 61                                   Cutting for Stone    Abraham Verghese
# 67                                        East of Eden      John Steinbeck
# 85                                     Game of Thrones              Martin
# 111                                      Invisible Man       Ralph Ellison
# 216                        The Bonfire of the Vanities           Tom Wolfe
# 256        The Intelligent Investor: (Revised Edition)     Benjamin Graham
# 257      The Invisible Bridge (Vintage Contemporaries)            Orringer
# 286  The Snowball: Warren Buffett and the Business ...     Alice Schroeder
# 308     To the End of the Land (Vintage International)            Grossman
#
#      List Price  NumPages
# 3         15.99     672.0
# 4         30.50     720.0
# 10        17.00     624.0
# 11        17.00     720.0
# 26        18.00     624.0
# 32        20.00     896.0
# 55         6.99      32.0
# 60        15.95     667.0
# 61        15.95     667.0
# 67        11.50     601.0
# 85        17.00     720.0
# 111       15.95     608.0
# 216       22.00     704.0
# 256       21.99     640.0
# 257       15.95     784.0
# 286       20.00     832.0
# 308       15.95     672.0

# %%
amazonbooks.loc[ (amazonbooks.Hard_or_Paper!='H')&((amazonbooks.NumPages<50)|(amazonbooks.NumPages>600)),('Title','Author','List Price','NumPages')]
# Out:
#                                                  Title              Author  \
# 3              1421: The Year China Discovered America       Gavin Menzies
# 4      1493: Uncovering the New World Columbus Created     Charles C. Mann
# 10                                      A Fine Balance     Rohinton Mistry
# 11           A Game of Thrones: A song of fire and ice  George R.R. Martin
# 26                   Ada, or Ardor: A Family Chronicle    Vladimir Nabokov
# 32                                     Andrew Carnegie         David Nasaw
# 55                   Cloudy With a Chance of Meatballs        Judi Barrett
# 60                                   Cutting for Stone            Verghese
# 61                                   Cutting for Stone    Abraham Verghese
# 67                                        East of Eden      John Steinbeck
# 85                                     Game of Thrones              Martin
# 111                                      Invisible Man       Ralph Ellison
# 216                        The Bonfire of the Vanities           Tom Wolfe
# 256        The Intelligent Investor: (Revised Edition)     Benjamin Graham
# 257      The Invisible Bridge (Vintage Contemporaries)            Orringer
# 286  The Snowball: Warren Buffett and the Business ...     Alice Schroeder
# 308     To the End of the Land (Vintage International)            Grossman
#
#      List Price  NumPages
# 3         15.99     672.0
# 4         30.50     720.0
# 10        17.00     624.0
# 11        17.00     720.0
# 26        18.00     624.0
# 32        20.00     896.0
# 55         6.99      32.0
# 60        15.95     667.0
# 61        15.95     667.0
# 67        11.50     601.0
# 85        17.00     720.0
# 111       15.95     608.0
# 216       22.00     704.0
# 256       21.99     640.0
# 257       15.95     784.0
# 286       20.00     832.0
# 308       15.95     672.0

# %% [markdown]
# ### Compound Conditon Boolean Selection
#
# - `&`, `|`, `==`, `!=`

# %%
# This would have been a good example to include as well, but I didn't think to do so
amazonbooks.loc[(amazonbooks.Hard_or_Paper=='P')&(amazonbooks.NumPages<100),
                ('Title','Author','List Price')].sort_values('List Price')

# %% [markdown]
# Also forgot to mention/summarize
# - `.value_counts()`
# - errata: ~~`.count()`~~ `.size()` in the first summary above
